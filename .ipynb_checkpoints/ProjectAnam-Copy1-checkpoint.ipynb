# %%
from pandas import DataFrame
import pandas as pd
import numpy as np

# %%
from jsonapi_client import Session, Filter
import pycurl

API_BASE = 'https://www.ebi.ac.uk/metagenomics/api/latest/'

# %%
# 'studies' bisa diganti dengan target semisal 'sample' ; 'MGYS00001939' merupakan accession
with Session(API_BASE) as s:
    std = s.get('studies', 'MGYS00001939').resource

# %%
#memunculkan study_name
std
# Out:
# <ResourceObject: studies: MGYS00001939 (1410979003136) (1410979003136)>

# %%
#melihat jumlah sample pada study di atas
x = std.samples
x = x[0]
x.sample_name
# Out:
# 'Bulk soil exposed to nanosilver, sample 2'

# %%
with Session(API_BASE) as s:
    std = s.get('studies', 'MGYS00001939').resource
print(std.accession)
sample = std.samples
#melihat informasi pada salah satu sample yang dipilih
df = pd.DataFrame([])
acc = []
sample_name = []
for x in sample:
    acc.append(x.accession)
    sample_name.append(x.sample_name)
    meta = x.sample_metadata
    meta = pd.DataFrame.from_dict(meta)
    meta = meta.set_index('key') 
    meta = meta.drop(columns='unit')
    meta = meta.transpose()
    df = df.append(meta)
acc = pd.DataFrame(acc, columns=['Accession'])
sample_name = pd.DataFrame(sample_name, columns=['Sample Name'])
df = df.reset_index()
df = df.drop(columns='index')
merged = acc.merge(sample_name, left_index=True, right_index=True, how='inner')
merged = merged.merge(df, left_index=True, right_index=True, how='inner')
merged
# Out:
# MGYS00001939
#      Accession                                        Sample Name  \
# 0   ERS1851088          Bulk soil exposed to nanosilver, sample 2
# 1   ERS1851084      Bulk soil not exposed to nanosilver, sample 1
# 2   ERS1851093   Rhizosphere soil exposed to nanosilver, sample 1
# 3   ERS1851087          Bulk soil exposed to nanosilver, sample 1
# 4   ERS1851094   Rhizosphere soil exposed to nanosilver, sample 2
# 5   ERS1851086      Bulk soil not exposed to nanosilver, sample 3
# 6   ERS1851095   Rhizosphere soil exposed to nanosilver, sample 3
# 7   ERS1851090  Rhizosphere soil not exposed to nanosilver, sa...
# 8   ERS1851092  Rhizosphere soil not exposed to nanosilver, sa...
# 9   ERS1851085      Bulk soil not exposed to nanosilver, sample 2
# 10  ERS1851091  Rhizosphere soil not exposed to nanosilver, sa...
# 11  ERS1851089          Bulk soil exposed to nanosilver, sample 3
#
#    investigation type geographic location (longitude)  \
# 0   metatranscriptome                        5.411394
# 1   metatranscriptome                        5.411394
# 2   metatranscriptome                        5.411394
# 3   metatranscriptome                        5.411394
# 4   metatranscriptome                        5.411394
# 5   metatranscriptome                        5.411394
# 6   metatranscriptome                        5.411394
# 7   metatranscriptome                        5.411394
# 8   metatranscriptome                        5.411394
# 9   metatranscriptome                        5.411394
# 10  metatranscriptome                        5.411394
# 11  metatranscriptome                        5.411394
#
#    geographic location (country and/or sea,region) collection date  \
# 0                                          Belgium      2015-03-18
# 1                                          Belgium      2015-03-18
# 2                                          Belgium      2015-03-18
# 3                                          Belgium      2015-03-18
# 4                                          Belgium      2015-03-18
# 5                                          Belgium      2015-03-18
# 6                                          Belgium      2015-03-18
# 7                                          Belgium      2015-03-18
# 8                                          Belgium      2015-03-18
# 9                                          Belgium      2015-03-18
# 10                                         Belgium      2015-03-18
# 11                                         Belgium      2015-03-18
#
#    environment (biome) environment (feature) environment (material)  \
# 0     area of cropland      area of cropland      agricultural soil
# 1     area of cropland      area of cropland      agricultural soil
# 2     area of cropland      area of cropland      agricultural soil
# 3     area of cropland      area of cropland      agricultural soil
# 4     area of cropland      area of cropland      agricultural soil
# 5     area of cropland      area of cropland      agricultural soil
# 6     area of cropland      area of cropland      agricultural soil
# 7     area of cropland      area of cropland      agricultural soil
# 8     area of cropland      area of cropland      agricultural soil
# 9     area of cropland      area of cropland      agricultural soil
# 10    area of cropland      area of cropland      agricultural soil
# 11    area of cropland      area of cropland      agricultural soil
#
#    environmental package sequencing method elevation  \
# 0                   soil          Illumina      46.0
# 1                   soil          Illumina      46.0
# 2                   soil          Illumina      46.0
# 3                   soil          Illumina      46.0
# 4                   soil          Illumina      46.0
# 5                   soil          Illumina      46.0
# 6                   soil          Illumina      46.0
# 7                   soil          Illumina      46.0
# 8                   soil          Illumina      46.0
# 9                   soil          Illumina      46.0
# 10                  soil          Illumina      46.0
# 11                  soil          Illumina      46.0
#
#    geographic location (latitude)     instrument model
# 0                        50.93487  Illumina HiSeq 4000
# 1                        50.93487  Illumina HiSeq 4000
# 2                        50.93487  Illumina HiSeq 4000
# 3                        50.93487  Illumina HiSeq 4000
# 4                        50.93487  Illumina HiSeq 4000
# 5                        50.93487  Illumina HiSeq 4000
# 6                        50.93487  Illumina HiSeq 4000
# 7                        50.93487  Illumina HiSeq 4000
# 8                        50.93487  Illumina HiSeq 4000
# 9                        50.93487  Illumina HiSeq 4000
# 10                       50.93487  Illumina HiSeq 4000
# 11                       50.93487  Illumina HiSeq 4000

# %%
for a in x.runs:
    for b in a.analyses:
        for c in b.downloads:
            print(c.url)
# Out:
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_1.fasta.gz
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_2.fasta.gz
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_3.fasta.gz
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_CDS_annotated.faa.gz
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_CDS_unannotated.faa.gz
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_interproscan.fasta.gz
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_noFunction.fasta.gz
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_ORF_unannotated.ffn.gz
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_readsWithpCDS.fasta.gz
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_GO_slim.csv
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_GO.csv
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_InterPro.tsv.gz
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_16SrRNA.fasta
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_23SrRNA.fasta
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_5SrRNA.fasta
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_otu_table_hdf5.biom
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_otu_table_json.biom
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_otu.tsv
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_pruned.tree
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_tRNA.fasta

# %%
blank = []
for x in sample:
    #print(x.sample_metadata)
    df = pd.DataFrame(x.sample_metadata)
    #print(df)
    index = np.where(df['key'].str.contains('location'))[0]
    blank.append(df.iloc[index, :])
    index = np.where(df['key'].str.contains('biome'))[0]
    blank.append(df.iloc[index, :])
    index = np.where(df['key'].str.contains('elevation'))[0]
    blank.append(df.iloc[index, :])
    df_new = pd.concat(blank)
df_new
# Out:
#                                                 key  unit             value
# 1                   geographic location (longitude)  None          5.411394
# 2   geographic location (country and/or sea,region)  None           Belgium
# 10                   geographic location (latitude)  None          50.93487
# 4                               environment (biome)  None  area of cropland
# 9                                         elevation  None              46.0
# 1                   geographic location (longitude)  None          5.411394
# 2   geographic location (country and/or sea,region)  None           Belgium
# 10                   geographic location (latitude)  None          50.93487
# 4                               environment (biome)  None  area of cropland
# 9                                         elevation  None              46.0
# 1                   geographic location (longitude)  None          5.411394
# 2   geographic location (country and/or sea,region)  None           Belgium
# 10                   geographic location (latitude)  None          50.93487
# 4                               environment (biome)  None  area of cropland
# 9                                         elevation  None              46.0
# 1                   geographic location (longitude)  None          5.411394
# 2   geographic location (country and/or sea,region)  None           Belgium
# 10                   geographic location (latitude)  None          50.93487
# 4                               environment (biome)  None  area of cropland
# 9                                         elevation  None              46.0
# 1                   geographic location (longitude)  None          5.411394
# 2   geographic location (country and/or sea,region)  None           Belgium
# 10                   geographic location (latitude)  None          50.93487
# 4                               environment (biome)  None  area of cropland
# 9                                         elevation  None              46.0
# 1                   geographic location (longitude)  None          5.411394
# 2   geographic location (country and/or sea,region)  None           Belgium
# 10                   geographic location (latitude)  None          50.93487
# 4                               environment (biome)  None  area of cropland
# 9                                         elevation  None              46.0
# 1                   geographic location (longitude)  None          5.411394
# 2   geographic location (country and/or sea,region)  None           Belgium
# 10                   geographic location (latitude)  None          50.93487
# 4                               environment (biome)  None  area of cropland
# 9                                         elevation  None              46.0
# 1                   geographic location (longitude)  None          5.411394
# 2   geographic location (country and/or sea,region)  None           Belgium
# 10                   geographic location (latitude)  None          50.93487
# 4                               environment (biome)  None  area of cropland
# 9                                         elevation  None              46.0
# 1                   geographic location (longitude)  None          5.411394
# 2   geographic location (country and/or sea,region)  None           Belgium
# 10                   geographic location (latitude)  None          50.93487
# 4                               environment (biome)  None  area of cropland
# 9                                         elevation  None              46.0
# 1                   geographic location (longitude)  None          5.411394
# 2   geographic location (country and/or sea,region)  None           Belgium
# 10                   geographic location (latitude)  None          50.93487
# 4                               environment (biome)  None  area of cropland
# 9                                         elevation  None              46.0
# 1                   geographic location (longitude)  None          5.411394
# 2   geographic location (country and/or sea,region)  None           Belgium
# 10                   geographic location (latitude)  None          50.93487
# 4                               environment (biome)  None  area of cropland
# 9                                         elevation  None              46.0
# 1                   geographic location (longitude)  None          5.411394
# 2   geographic location (country and/or sea,region)  None           Belgium
# 10                   geographic location (latitude)  None          50.93487
# 4                               environment (biome)  None  area of cropland
# 9                                         elevation  None              46.0

# %%
sample = x.sample_metadata
index = np.where(df['key'].str.contains('location'))[0]
for i in index:
    print(sample[i]['key'])
    print(sample[i]['value'])
# Out:
# geographic location (longitude)
# 5.411394
# geographic location (country and/or sea,region)
# Belgium
# geographic location (latitude)
# 50.93487

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-49abc791e070> in <module>()
#       1 for x in sample:
# ----> 2     df = pd.DataFrame.from_dict(x)
#       3     df = df.set_index('key')
#       4     df = df.drop(columns='unit')
#       5     df = df.transpose()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in from_dict(cls, data, orient, dtype, columns)
#     983             raise ValueError('only recognize index or columns for orient')
#     984
# --> 985         return cls(data, index=index, columns=columns, dtype=dtype)
#     986
#     987     def to_dict(self, orient='dict', into=dict):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7313     # figure out the index, if necessary
#    7314     if index is None:
# -> 7315         index = extract_index(arrays)
#    7316
#    7317     # don't force copy because getting jammed in an ndarray anyway
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in extract_index(data)
#    7350
#    7351         if not indexes and not raw_lengths:
# -> 7352             raise ValueError('If using all scalar values, you must pass'
#    7353                              ' an index')
#    7354
#
# ValueError: If using all scalar values, you must pass an index

# %%
#memasukkan sample yang dipilih ke bentuk kolom
df = pd.DataFrame(sample[0].sample_metadata)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-4c64cd0fb6d6> in <module>()
#       1 #memasukkan sample yang dipilih ke bentuk kolom
# ----> 2 df = pd.DataFrame(sample[0].sample_metadata)
#       3 df
#
# NameError: name 'sample' is not defined

# %%
blank = []

# %%
#membuat index baru dari list 'key' yang dipilih
index = np.where(df['key'].str.contains('location'))[0]
blank.append(df.iloc[index, :])
index = np.where(df['key'].str.contains('biome'))[0]
blank.append(df.iloc[index, :])
index = np.where(df['key'].str.contains('elevation'))[0]
blank.append(df.iloc[index, :])

# %%
#'key' yang dilih dijadikan data frame baru
df_new = pd.concat(blank)
df_new
# Out:
#                                                 key  unit             value
# 1                   geographic location (longitude)  None          5.411394
# 2   geographic location (country and/or sea,region)  None           Belgium
# 10                   geographic location (latitude)  None          50.93487
# 4                               environment (biome)  None  area of cropland
# 9                                         elevation  None              46.0

# %%
filename_sample = ''

# %%
#membuat loop accession di dalam bentuk list
for i in sample:
    #print('sample: '+str(i.accession))
    for x in i.runs:
        #print('runs: '+str(x.accession))
        for y in x.analyses:
            #print('analyses: '+str(y.accession))
            for z in y.downloads:
                if 'json.biom' in z.url:
                    print(z.url)
# Out:
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135103/file/ERR2061845_MERGED_FASTQ_otu_table_json.biom
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135102/file/ERR2061841_MERGED_FASTQ_otu_table_json.biom
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135099/file/ERR2061850_MERGED_FASTQ_otu_table_json.biom
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135098/file/ERR2061844_MERGED_FASTQ_otu_table_json.biom
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135093/file/ERR2061851_MERGED_FASTQ_otu_table_json.biom
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135104/file/ERR2061843_MERGED_FASTQ_otu_table_json.biom
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135094/file/ERR2061852_MERGED_FASTQ_otu_table_json.biom
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135095/file/ERR2061847_MERGED_FASTQ_otu_table_json.biom
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135096/file/ERR2061849_MERGED_FASTQ_otu_table_json.biom
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135100/file/ERR2061842_MERGED_FASTQ_otu_table_json.biom
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135101/file/ERR2061848_MERGED_FASTQ_otu_table_json.biom
# https://www.ebi.ac.uk/metagenomics/api/v1/analyses/MGYA00135097/file/ERR2061846_MERGED_FASTQ_otu_table_json.biom

# %%
#membuat folder
from pathlib import Path
import os
Study = 'MGYS00001939'
_dir = os.getcwd()#'D:\\Seminar\\Seminar_Anam'
print(_dir)
_dir = os.path.join(_dir, 'Study%s' % Study)
if not os.path.exists(_dir):
    os.makedirs(_dir)
#%rmdir(Study+str)
#with open('_dir'+i.accession+'.biom', 'wb') as f:
    #c = pycurl.Curl()
    #c.setopt(c.URL, z.url)
    #c.setopt(c.WRITEDATA, f)
    #c.perform()
#c.close()
# Out:
# E:\Jupyter_Lab\Seminar_Anam
